# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
main_df = pd.read_csv('https://breathecode.herokuapp.com/asset/internal-link?id=2325&path=adult-census-income.csv')
main_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
main_df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
(main_df['age']=='?').sum()
# Out:
# np.int64(0)

# %%
main_df['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
main_df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
main_df= main_df.replace("?",np.nan)

# %%
main_df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
main_df.isna().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
main_df['capital.gain'].value_counts()
# Out:
# capital.gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 2538         1
# 2387         1
# 1455         1
# 1639         1
# 1111         1
# Name: count, Length: 119, dtype: int64

# %%
main_df[main_df['workclass'].isna()]
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 14      51       NaN  172175     Doctorate             16       Never-married
# 24      61       NaN  135285       HS-grad              9  Married-civ-spouse
# 44      71       NaN  100820       HS-grad              9  Married-civ-spouse
# ...    ...       ...     ...           ...            ...                 ...
# 32533   35       NaN  320084     Bachelors             13  Married-civ-spouse
# 32534   30       NaN   33811     Bachelors             13       Never-married
# 32541   71       NaN  287372     Doctorate             16  Married-civ-spouse
# 32543   41       NaN  202822       HS-grad              9           Separated
# 32544   72       NaN  129912       HS-grad              9  Married-civ-spouse
#
# ...

# %%
main_df[main_df['workclass'].isna()]['occupation'].value_counts()
#workclass and occupation is higly correlated
# Out:
# Series([], Name: count, dtype: int64)

# %%
main_df[['workclass','occupation']] = (main_df[['workclass','occupation']].fillna('unknow'))

# %%
main_df.isna().sum()
# Out:
# age                 0
# workclass           0
# fnlwgt              0
# education           0
# education.num       0
# marital.status      0
# occupation          0
# relationship        0
# race                0
# sex                 0
# capital.gain        0
# capital.loss        0
# hours.per.week      0
# native.country    583
# income              0
# dtype: int64

# %%
main_df[main_df['workclass'].isna()]['income'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
main_df[main_df['workclass'].isna()]['occupation'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
main_df['native.country'].value_counts()
# Out:
# native.country
# United-States                 29170
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
main_df[main_df['native.country'].isna()]
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 9       41           Private   70037  Some-college             10
# 18      22           Private  119592    Assoc-acdm             12
# 65      60      Self-emp-inc  226355     Assoc-voc             11
# 86      39  Self-emp-not-inc  218490   Prof-school             15
# 87      43       Federal-gov  156996   Prof-school             15
# ...    ...               ...     ...           ...            ...
# 32459   44      Self-emp-inc   71556       Masters             14
# 32476   58      Self-emp-inc  181974     Doctorate             16
# 32498   42  Self-emp-not-inc  217597       HS-grad              9
# 32515   39           Private  107302       HS-grad              9
# 32528   81            unknow  120478     Assoc-voc             11
#
#            marital.status         occupation   relationship  \
# 9           Never-married       Craft-repair      Unmarried
# ...

# %%
main_df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
main_df[main_df['income']==">50K"]['education'].value_counts()
# Out:
# education
# Bachelors       2221
# HS-grad         1675
# Some-college    1387
# Masters          959
# Prof-school      423
# Assoc-voc        361
# Doctorate        306
# Assoc-acdm       265
# 10th              62
# 11th              60
# 7th-8th           40
# 12th              33
# 9th               27
# 5th-6th           16
# 1st-4th            6
# Name: count, dtype: int64

# %%
sns.histplot(main_df['hours.per.week'])
# Out:
# <Axes: xlabel='hours.per.week', ylabel='Count'>

# %%
main_df['hours.per.week'].value_counts().sort_values()
# Out:
# hours.per.week
# 87        1
# 82        1
# 94        1
# 92        1
# 74        1
#       ...
# 35     1297
# 60     1475
# 45     1824
# 50     2819
# 40    15217
# Name: count, Length: 94, dtype: int64

# %%
main_df = main_df.drop(columns='education')

# %%
main_df.head()
# Out:
#    age workclass  fnlwgt  education.num marital.status         occupation  \
# 0   90    unknow   77053              9        Widowed             unknow
# 1   82   Private  132870              9        Widowed    Exec-managerial
# 2   66    unknow  186061             10        Widowed             unknow
# 3   54   Private  140359              4       Divorced  Machine-op-inspct
# 4   41   Private  264663             10      Separated     Prof-specialty
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
# 1  Not-in-family  White  Female             0          4356              18
# 2      Unmarried  Black  Female             0          4356              40
# 3      Unmarried  White  Female             0          3900              40
# 4      Own-child  White  Female             0          3900              40
#
#   native.country income
# 0  United-States  <=50K
# ...

# %%
u={"<=50K":0,
">50K":1}
main_df['income']= main_df['income'].map(u)

# %%
main_df['income'].value_counts()
# Out:
# income
# 0    24720
# 1     7841
# Name: count, dtype: int64

# %%
main_df['sex'].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %%
main_df['sex']=main_df['sex'].map({"Male":1,"Female":0})

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education.num   32561 non-null  int64
#  4   marital.status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  int64
#  9   capital.gain    32561 non-null  int64
#  10  capital.loss    32561 non-null  int64
#  11  hours.per.week  32561 non-null  int64
#  12  native.country  31978 non-null  object
#  13  income          32561 non-null  int64
# dtypes: int64(8), object(6)
# memory usage: 3.5+ MB

# %%
main_df['native.country'].mode()
# Out:
# 0    United-States
# Name: native.country, dtype: object

# %%
main_df['native.country']= main_df['native.country'].fillna(main_df['native.country'].mode()[0])

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education.num   32561 non-null  int64
#  4   marital.status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  int64
#  9   capital.gain    32561 non-null  int64
#  10  capital.loss    32561 non-null  int64
#  11  hours.per.week  32561 non-null  int64
#  12  native.country  32561 non-null  object
#  13  income          32561 non-null  int64
# dtypes: int64(8), object(6)
# memory usage: 3.5+ MB

# %%
main_df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
main_df['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# unknow               1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
main_df['workclass'] = main_df['workclass'].replace(['Without-pay','Never-worked'],'other')

# %%
main_df['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# unknow               1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# other                  21
# Name: count, dtype: int64

# %%
work_class_dummies = pd.get_dummies(main_df['workclass'],prefix='workclass',drop_first=False,dtype=int)

# %%
main_df=pd.concat([main_df, work_class_dummies], axis=1)

# %%
main_df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education.num', 'marital.status',
#        'occupation', 'relationship', 'race', 'sex', 'capital.gain',
#        'capital.loss', 'hours.per.week', 'native.country', 'income',
#        'workclass_Federal-gov', 'workclass_Local-gov', 'workclass_Private',
#        'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc',
#        'workclass_State-gov', 'workclass_other', 'workclass_unknow'],
#       dtype='object')

# %%
main_df.head()
# Out:
#    age workclass  fnlwgt  education.num marital.status         occupation  \
# 0   90    unknow   77053              9        Widowed             unknow
# 1   82   Private  132870              9        Widowed    Exec-managerial
# 2   66    unknow  186061             10        Widowed             unknow
# 3   54   Private  140359              4       Divorced  Machine-op-inspct
# 4   41   Private  264663             10      Separated     Prof-specialty
#
#     relationship   race  sex  capital.gain  ...  native.country  income  \
# 0  Not-in-family  White    0             0  ...   United-States       0
# 1  Not-in-family  White    0             0  ...   United-States       0
# 2      Unmarried  Black    0             0  ...   United-States       0
# 3      Unmarried  White    0             0  ...   United-States       0
# 4      Own-child  White    0             0  ...   United-States       0
#
#   workclass_Federal-gov  workclass_Local-gov  workclass_Private  \
# ...

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         32561 non-null  int64
#  1   workclass                   32561 non-null  object
#  2   fnlwgt                      32561 non-null  int64
#  3   education.num               32561 non-null  int64
#  4   marital.status              32561 non-null  object
#  5   occupation                  32561 non-null  object
#  6   relationship                32561 non-null  object
#  7   race                        32561 non-null  object
#  8   sex                         32561 non-null  int64
#  9   capital.gain                32561 non-null  int64
#  10  capital.loss                32561 non-null  int64
#  11  hours.per.week              32561 non-null  int64
#  12  native.country              32561 non-null  object
# ...

# %%
main_df= main_df.drop(columns=['workclass'])

# %%
main_df['marital.status'].value_counts()
# Out:
# marital.status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64

# %%
single_maried = {
    'Married-civ-spouse': 'Married',
    'Married-spouse-absent': 'Married',
    'Married-AF-spouse': 'Married',
    'Never-married': 'Single',
    'Divorced': 'Single',
    'Separated': 'Single',
    'Widowed': 'Single'
}

main_df['marital.status'] = main_df['marital.status'].map(single_maried)

# %%
main_df['marital.status'].value_counts()
# Out:
# marital.status
# Single     17144
# Married    15417
# Name: count, dtype: int64

# %%
marialstatus_dummies = pd.get_dummies(main_df['marital.status'],prefix='marital.status',drop_first=False,dtype=int)

# %%
marialstatus_dummies.head()
# Out:
#    marital.status_Married  marital.status_Single
# 0                       0                      1
# 1                       0                      1
# 2                       0                      1
# 3                       0                      1
# 4                       0                      1

# %%
main_df= pd.concat([main_df,marialstatus_dummies],axis=1)

# %%
main_df= main_df.drop(columns=['marital.status'])

# %%
main_df.head()
# Out:
#    age  fnlwgt  education.num         occupation   relationship   race  sex  \
# 0   90   77053              9             unknow  Not-in-family  White    0
# 1   82  132870              9    Exec-managerial  Not-in-family  White    0
# 2   66  186061             10             unknow      Unmarried  Black    0
# 3   54  140359              4  Machine-op-inspct      Unmarried  White    0
# 4   41  264663             10     Prof-specialty      Own-child  White    0
#
#    capital.gain  capital.loss  hours.per.week  ... workclass_Federal-gov  \
# 0             0          4356              40  ...                     0
# 1             0          4356              18  ...                     0
# 2             0          4356              40  ...                     0
# 3             0          3900              40  ...                     0
# 4             0          3900              40  ...                     0
#
#    workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# ...

# %%
main_df['race'].value_counts()
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
main_df['race'] = main_df['race'].replace(['Asian-Pac-Islander','Amer-Indian-Eskimo','Other'],'other')

# %%
main_df['race'].value_counts()
# Out:
# race
# White    27816
# Black     3124
# other     1621
# Name: count, dtype: int64

# %%
ethiciny = pd.get_dummies(main_df['race'],prefix='race',drop_first=False,dtype=int)

# %%
ethiciny.head()
# Out:
#    race_Black  race_White  race_other
# 0           0           1           0
# 1           0           1           0
# 2           1           0           0
# 3           0           1           0
# 4           0           1           0

# %%
main_df = pd.concat([main_df,ethiciny],axis=1)

# %%
main_df = main_df.drop(columns=['race'])

# %%
main_df.head()
# Out:
#    age  fnlwgt  education.num         occupation   relationship  sex  \
# 0   90   77053              9             unknow  Not-in-family    0
# 1   82  132870              9    Exec-managerial  Not-in-family    0
# 2   66  186061             10             unknow      Unmarried    0
# 3   54  140359              4  Machine-op-inspct      Unmarried    0
# 4   41  264663             10     Prof-specialty      Own-child    0
#
#    capital.gain  capital.loss  hours.per.week native.country  ...  \
# 0             0          4356              40  United-States  ...
# 1             0          4356              18  United-States  ...
# 2             0          4356              40  United-States  ...
# 3             0          3900              40  United-States  ...
# 4             0          3900              40  United-States  ...
#
#    workclass_Self-emp-inc  workclass_Self-emp-not-inc  workclass_State-gov  \
# ...

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         32561 non-null  int64
#  1   fnlwgt                      32561 non-null  int64
#  2   education.num               32561 non-null  int64
#  3   occupation                  32561 non-null  object
#  4   relationship                32561 non-null  object
#  5   sex                         32561 non-null  int64
#  6   capital.gain                32561 non-null  int64
#  7   capital.loss                32561 non-null  int64
#  8   hours.per.week              32561 non-null  int64
#  9   native.country              32561 non-null  object
#  10  income                      32561 non-null  int64
#  11  workclass_Federal-gov       32561 non-null  int64
#  12  workclass_Local-gov         32561 non-null  int64
# ...

# %%
main_df['relationship'].value_counts()
# Out:
# relationship
# Husband           13193
# Not-in-family      8305
# Own-child          5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64

# %%
relationship = pd.get_dummies(main_df['relationship'],prefix='relationship',drop_first=False,dtype=int)

# %%
main_df = pd.concat([main_df,relationship],axis=1)

# %%
main_df=main_df.drop(columns=['relationship'])

# %%
main_df.head()
# Out:
#    age  fnlwgt  education.num         occupation  sex  capital.gain  \
# 0   90   77053              9             unknow    0             0
# 1   82  132870              9    Exec-managerial    0             0
# 2   66  186061             10             unknow    0             0
# 3   54  140359              4  Machine-op-inspct    0             0
# 4   41  264663             10     Prof-specialty    0             0
#
#    capital.loss  hours.per.week native.country  income  ...  \
# 0          4356              40  United-States       0  ...
# 1          4356              18  United-States       0  ...
# 2          4356              40  United-States       0  ...
# 3          3900              40  United-States       0  ...
# 4          3900              40  United-States       0  ...
#
#    marital.status_Single  race_Black  race_White  race_other  \
# 0                      1           0           1           0
# 1                      1           0           1           0
# ...

# %%
main_df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# unknow               1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: int64

# %%
main_df = main_df.replace(['Armed-Forces','Protective-serv'],'Armed-protective')

# %%
main_df = main_df.replace(['Transport-moving','Handlers-cleaners'],'Transport-Handlers')

# %%
main_df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty        4140
# Craft-repair          4099
# Exec-managerial       4066
# Adm-clerical          3770
# Sales                 3650
# Other-service         3295
# Transport-Handlers    2967
# Machine-op-inspct     2002
# unknow                1843
# Farming-fishing        994
# Tech-support           928
# Armed-protective       658
# Priv-house-serv        149
# Name: count, dtype: int64

# %%
main_df = main_df.replace(['Priv-house-serv','Other-service'],'Other-service')

# %%
main_df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty        4140
# Craft-repair          4099
# Exec-managerial       4066
# Adm-clerical          3770
# Sales                 3650
# Other-service         3444
# Transport-Handlers    2967
# Machine-op-inspct     2002
# unknow                1843
# Farming-fishing        994
# Tech-support           928
# Armed-protective       658
# Name: count, dtype: int64

# %%
occupation = pd.get_dummies(main_df['occupation'],prefix='occupation',dtype=int,drop_first=False)

# %%
main_df = pd.concat([main_df,occupation],axis=1)

# %%
main_df=main_df.drop(columns=['occupation'])

# %%
main_df.head()
# Out:
#    age  fnlwgt  education.num  sex  capital.gain  capital.loss  \
# 0   90   77053              9    0             0          4356
# 1   82  132870              9    0             0          4356
# 2   66  186061             10    0             0          4356
# 3   54  140359              4    0             0          3900
# 4   41  264663             10    0             0          3900
#
#    hours.per.week native.country  income  workclass_Federal-gov  ...  \
# 0              40  United-States       0                      0  ...
# 1              18  United-States       0                      0  ...
# 2              40  United-States       0                      0  ...
# 3              40  United-States       0                      0  ...
# 4              40  United-States       0                      0  ...
#
#    occupation_Craft-repair  occupation_Exec-managerial  \
# 0                        0                           0
# 1                        0                           1
# ...

# %%
main_df['native.country'].value_counts()
# Out:
# native.country
# United-States                 29753
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
main_df['native_country_US'] = (main_df['native.country'] == 'United-States').astype(int)

# %%
main_df= main_df.drop(columns=['native.country'])

# %%
main_df.head()
# Out:
#    age  fnlwgt  education.num  sex  capital.gain  capital.loss  \
# 0   90   77053              9    0             0          4356
# 1   82  132870              9    0             0          4356
# 2   66  186061             10    0             0          4356
# 3   54  140359              4    0             0          3900
# 4   41  264663             10    0             0          3900
#
#    hours.per.week  income  workclass_Federal-gov  workclass_Local-gov  ...  \
# 0              40       0                      0                    0  ...
# 1              18       0                      0                    0  ...
# 2              40       0                      0                    0  ...
# 3              40       0                      0                    0  ...
# 4              40       0                      0                    0  ...
#
#    occupation_Exec-managerial  occupation_Farming-fishing  \
# 0                           0                           0
# ...

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            32561 non-null  int64
#  1   fnlwgt                         32561 non-null  int64
#  2   education.num                  32561 non-null  int64
#  3   sex                            32561 non-null  int64
#  4   capital.gain                   32561 non-null  int64
#  5   capital.loss                   32561 non-null  int64
#  6   hours.per.week                 32561 non-null  int64
#  7   income                         32561 non-null  int64
#  8   workclass_Federal-gov          32561 non-null  int64
#  9   workclass_Local-gov            32561 non-null  int64
#  10  workclass_Private              32561 non-null  int64
#  11  workclass_Self-emp-inc         32561 non-null  int64
# ...

# %%
num=['age','fnlwgt','education.num','capital.gain','capital.loss','hours.per.week'] ## we need the scale those columns

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()
main_df[num] = sc.fit_transform(main_df[num])
#main_df[num]

# %%
main_df.head()
# Out:
#         age    fnlwgt  education.num  sex  capital.gain  capital.loss  \
# 0  3.769612 -1.067997      -0.420060    0      -0.14592     10.593507
# 1  3.183112 -0.539169      -0.420060    0      -0.14592     10.593507
# 2  2.010110 -0.035220      -0.031360    0      -0.14592     10.593507
# 3  1.130359 -0.468215      -2.363558    0      -0.14592      9.461864
# 4  0.177296  0.709482      -0.031360    0      -0.14592      9.461864
#
#    hours.per.week  income  workclass_Federal-gov  workclass_Local-gov  ...  \
# 0       -0.035429       0                      0                    0  ...
# 1       -1.817204       0                      0                    0  ...
# 2       -0.035429       0                      0                    0  ...
# 3       -0.035429       0                      0                    0  ...
# 4       -0.035429       0                      0                    0  ...
#
#    occupation_Exec-managerial  occupation_Farming-fishing  \
# ...

# %%
x = main_df.drop(columns=['income'])
y = main_df['income']

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim = cosine_similarity(x)
cosine_sim.shape
# Out:
# (32561, 32561)

# %%
index_ = 0
score = cosine_sim[index_]
top5 = score.argsort()[-6:][::-1]
top5 = top5[top5 != index_]
top5
# Out:
# array([  1,   2, 213,  48, 310])

# %%
y[top5].mode()[0]
# Out:
# np.int64(0)

# %%
def recommend_basic(index_, df, cosine_sim, k=5):
    scores = cosine_sim[index_]
    sorted_idx = scores.argsort()[::-1]

    results = []

    for i in sorted_idx:
        if i != index_:
            results.append(i)
        if len(results) == k:
            break

    return df.loc[results]

# %%
recommend_basic(0, main_df, cosine_sim, k=5)
# Out:
#           age    fnlwgt  education.num  sex  capital.gain  capital.loss  \
# 1    3.183112 -0.539169       -0.42006    0      -0.14592     10.593507
# 2    2.010110 -0.035220       -0.03136    0      -0.14592     10.593507
# 213  1.790173  0.419757       -0.42006    0      -0.14592      5.255429
# 48   2.156735  0.021541       -0.03136    0      -0.14592      5.880810
# 310  1.203672 -0.629061       -0.42006    0      -0.14592      4.749167
#
#      hours.per.week  income  workclass_Federal-gov  workclass_Local-gov  ...  \
# 1         -1.817204       0                      0                    0  ...
# 2         -0.035429       0                      0                    0  ...
# 213       -0.035429       0                      0                    0  ...
# 48        -0.035429       0                      0                    0  ...
# 310       -0.035429       0                      0                    0  ...
#
#      occupation_Exec-managerial  occupation_Farming-fishing  \
# ...
